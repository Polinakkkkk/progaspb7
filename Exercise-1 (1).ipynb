# %%
ice_cream_rating = 9
sleep_rating = 10
happiness_rating = (ice_cream_rating + sleep_rating)/2
print('мне нравится есть мороженое на',ice_cream_rating , 'мне нравится спать на',sleep_rating) 
print(happiness_rating)
print(type(ice_cream_rating))
print(type(sleep_rating))
print(type(happiness_rating))
# Out:
# мне нравится есть мороженое на 9 мне нравится спать на 10
# 9.5
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %%
first_name = 'Полина'
last_name = 'Калачёва'
print(first_name, last_name)
# Out:
# Полина Калачёва

# %%
print('Меня зовут',first_name, last_name,',и я ставлю мороженому',ice_cream_rating,'из 10!',"\n"'Я',first_name, last_name,',и мой рейтинг удовольствия от сна —',sleep_rating,'из 10!',"\n"'Исходя из вышеперечисленных факторов, мой рейтинг счастья составляет',happiness_rating,'из 10.')
# Out:
# Меня зовут Полина Калачёва ,и я ставлю мороженому 9 из 10!
# Я Полина Калачёва ,и мой рейтинг удовольствия от сна — 10 из 10!
# Исходя из вышеперечисленных факторов, мой рейтинг счастья составляет 9.5 из 10.
